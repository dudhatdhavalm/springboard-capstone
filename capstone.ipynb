# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_accept = pd.read_csv("data/datasets_902_370089_accepted_2007_to_2018Q4.csv")
# Out:
# /mnt/BA504CE3504CA7C9/Work/Python/Pract/ML/env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_accept = df_accept.sample(frac=0.05)

# %%
len(df_accept)
# Out:
# 33910

# %%
pd.options.display.max_columns
# Out:
# 151

# %%
pd.options.display.max_columns = len(df_accept.columns)

# %%
df_accept.shape
# Out:
# (678210, 151)

# %%
df_accept.head(5)
# Out:
#                 id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 128651    60983536        NaN    15000.0      15000.0          15000.0
# 258055    50486925        NaN    28000.0      28000.0          28000.0
# 2039024  125938434        NaN    15000.0      15000.0          15000.0
# 489385   127969743        NaN     5000.0       5000.0           5000.0
# 22313     66435932        NaN    21000.0      21000.0          21000.0
#
#                term  int_rate  installment grade sub_grade  \
# 128651    60 months      9.99       318.64     B        B3
# 258055    60 months     13.99       651.37     C        C4
# 2039024   36 months      6.72       461.24     A        A3
# 489385    36 months     10.91       163.49     B        B4
# 22313     60 months     12.59       473.42     C        C2
#
#                    emp_title emp_length home_ownership  annual_inc  \
# 128651         medical coder    5 years       MORTGAGE     65000.0
# 258055   Ingineering Manager  10+ years       MORTGAGE    148000.0
# 2039024    Operating Manager  10+ years       MORTGAGE    104000.0
# 489385                   NaN        NaN       MORTGAGE     32000.0
# 22313                  Owner    4 years           RENT    110000.0
#
#         verification_status   issue_d  loan_status pymnt_plan  \
# 128651         Not Verified  Oct-2015  Charged Off          n
# 258055             Verified  Jun-2015   Fully Paid          n
# 2039024            Verified  Dec-2017   Fully Paid          n
# 489385             Verified  Feb-2018      Current          n
# 22313       Source Verified  Dec-2015  Charged Off          n
#
#                                                        url desc  \
# 128651   https://lendingclub.com/browse/loanDetail.acti...  NaN
# 258055   https://lendingclub.com/browse/loanDetail.acti...  NaN
# 2039024  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 489385   https://lendingclub.com/browse/loanDetail.acti...  NaN
# 22313    https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                     purpose                    title zip_code addr_state  \
# 128651   debt_consolidation       Debt consolidation    707xx         LA
# 258055   debt_consolidation       Debt consolidation    750xx         TX
# 2039024         credit_card  Credit card refinancing    212xx         MD
# 489385   debt_consolidation       Debt consolidation    278xx         NC
# 22313    debt_consolidation       Debt consolidation    941xx         CA
#
#            dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 128651   21.27          1.0         Sep-2002           735.0            739.0
# 258055   14.77          0.0         Aug-2002           685.0            689.0
# 2039024  16.33          0.0         Jun-2001           720.0            724.0
# 489385   14.95          0.0         Mar-1983           675.0            679.0
# 22313    27.27          0.0         Dec-1999           700.0            704.0
#
#          inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 128651              0.0                     7.0                     NaN
# 258055              0.0                     NaN                     NaN
# 2039024             0.0                    31.0                     NaN
# 489385              0.0                     NaN                    46.0
# 22313               0.0                     NaN                     NaN
#
#          open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 128651       17.0      0.0     8766.0        25.9       40.0
# 258055       12.0      0.0    22748.0        92.5       30.0
# 2039024      13.0      0.0    19127.0        40.4       25.0
# 489385       19.0      1.0     8144.0        30.6       43.0
# 22313        11.0      0.0    74932.0        72.7       18.0
#
#         initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 128651                    w       0.00           0.00  11773.030000
# 258055                    w       0.00           0.00  36344.717659
# 2039024                   w       0.00           0.00  15922.762424
# 489385                    w    3379.03        3379.03   2122.340000
# 22313                     w       0.00           0.00   6814.040000
#
#          total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 128651          11773.03          8498.89        3274.14                 0.0
# 258055          36344.72         28000.00        8344.72                 0.0
# 2039024         15922.76         15000.00         922.76                 0.0
# 489385           2122.34          1620.97         501.37                 0.0
# 22313            6814.04          3218.67        2447.68                 0.0
#
#          recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 128651         0.00                   0.0000     Sep-2018           318.64
# 258055         0.00                   0.0000     Feb-2018         16195.77
# 2039024        0.00                   0.0000     Feb-2019         10401.88
# 489385         0.00                   0.0000     Mar-2019           163.49
# 22313       1147.69                 206.5842     Dec-2016           473.42
#
#         next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 128651           NaN           Mar-2019                 554.0
# 258055           NaN           Mar-2019                 689.0
# 2039024          NaN           Feb-2019                 764.0
# 489385      Apr-2019           Mar-2019                 689.0
# 22313            NaN           Oct-2018                 599.0
#
#          last_fico_range_low  collections_12_mths_ex_med  \
# 128651                 550.0                         0.0
# 258055                 685.0                         0.0
# 2039024                760.0                         0.0
# 489385                 685.0                         0.0
# 22313                  595.0                         0.0
#
#          mths_since_last_major_derog  policy_code application_type  \
# 128651                           NaN          1.0       Individual
# 258055                           NaN          1.0       Individual
# 2039024                          NaN          1.0       Individual
# 489385                           NaN          1.0       Individual
# 22313                            NaN          1.0       Individual
#
#          annual_inc_joint  dti_joint verification_status_joint  \
# 128651                NaN        NaN                       NaN
# 258055                NaN        NaN                       NaN
# 2039024               NaN        NaN                       NaN
# 489385                NaN        NaN                       NaN
# 22313                 NaN        NaN                       NaN
#
#          acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 128651              0.0           0.0     251763.0          NaN          NaN
# 258055              0.0           0.0     219033.0          NaN          NaN
# 2039024             0.0           0.0     657988.0          0.0          2.0
# 489385              0.0           0.0      52250.0          1.0          0.0
# 22313               0.0           0.0      78967.0          NaN          NaN
#
#          open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 128651           NaN          NaN                 NaN           NaN      NaN
# 258055           NaN          NaN                 NaN           NaN      NaN
# 2039024          0.0          1.0                21.0       17750.0     46.0
# 489385           0.0          0.0                71.0           0.0      NaN
# 22313            NaN          NaN                 NaN           NaN      NaN
#
#          open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 128651           NaN          NaN         NaN       NaN           33800.0
# 258055           NaN          NaN         NaN       NaN           24600.0
# 2039024          0.0          1.0      6318.0      43.0           47400.0
# 489385           1.0          8.0      2846.0      33.0           26600.0
# 22313            NaN          NaN         NaN       NaN          103000.0
#
#          inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 128651      NaN          NaN           NaN                   6.0      14810.0
# 258055      NaN          NaN           NaN                   3.0      19912.0
# 2039024     0.0          0.0           1.0                   3.0      50614.0
# 489385      3.0          0.0           0.0                   8.0       3074.0
# 22313       NaN          NaN           NaN                   1.0       7179.0
#
#          bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 128651          17098.0     18.6                       0.0          0.0
# 258055           1488.0     92.0                       0.0          0.0
# 2039024         24273.0     44.1                       0.0          0.0
# 489385           2319.0     67.3                       0.0          0.0
# 22313           22194.0     75.9                       0.0          0.0
#
#          mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 128651                156.0                 133.0                    5.0
# 258055                151.0                 153.0                   25.0
# 2039024                36.0                 198.0                   24.0
# 489385                175.0                 181.0                    6.0
# 22313                 119.0                 192.0                   12.0
#
#          mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 128651              5.0       1.0                  14.0
# 258055             13.0       3.0                  43.0
# 2039024            19.0       5.0                  50.0
# 489385              6.0       1.0                  13.0
# 22313              12.0       0.0                  40.0
#
#          mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 128651                        NaN                    3.0
# 258055                        NaN                   13.0
# 2039024                      31.0                   11.0
# 489385                        NaN                   15.0
# 22313                         NaN                   17.0
#
#          mths_since_recent_revol_delinq  num_accts_ever_120_pd  \
# 128651                              NaN                    0.0
# 258055                              NaN                    0.0
# 2039024                            31.0                    0.0
# 489385                              NaN                    0.0
# 22313                               NaN                    0.0
#
#          num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# 128651              3.0              5.0          5.0        7.0       23.0
# 258055              5.0              7.0          6.0       10.0       15.0
# 2039024             5.0              5.0          7.0       14.0        3.0
# 489385              4.0              9.0          5.0       12.0        3.0
# 22313               8.0             10.0          8.0        8.0        5.0
#
#          num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# 128651             8.0           16.0                  5.0      17.0
# 258055             8.0           12.0                  7.0      12.0
# 2039024            8.0           17.0                  5.0      13.0
# 489385            17.0           37.0                  9.0      18.0
# 22313             10.0           13.0                 10.0      11.0
#
#          num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 128651                0.0           0.0                 0.0
# 258055                0.0           0.0                 0.0
# 2039024               0.0           0.0                 0.0
# 489385                0.0           0.0                 0.0
# 22313                 0.0           0.0                 0.0
#
#          num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 128651                  2.0            97.5               0.0
# 258055                  0.0           100.0              80.0
# 2039024                 0.0            96.0              28.6
# 489385                  1.0           100.0              60.0
# 22313                   1.0           100.0              62.5
#
#          pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 128651                    0.0        0.0         307402.0            46097.0
# 258055                    0.0        0.0         260249.0            52111.0
# 2039024                   0.0        0.0         745762.0            36877.0
# 489385                    1.0        0.0          99015.0             9200.0
# 22313                     0.0        0.0         123755.0            78967.0
#
#          total_bc_limit  total_il_high_credit_limit  revol_bal_joint  \
# 128651          21000.0                     46652.0              NaN
# 258055          18700.0                     41749.0              NaN
# 2039024         43400.0                     38962.0              NaN
# 489385           7100.0                         0.0              NaN
# 22313           92000.0                     20755.0              NaN
#
#          sec_app_fico_range_low  sec_app_fico_range_high  \
# 128651                      NaN                      NaN
# 258055                      NaN                      NaN
# 2039024                     NaN                      NaN
# 489385                      NaN                      NaN
# 22313                       NaN                      NaN
#
#         sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 128651                       NaN                     NaN               NaN
# 258055                       NaN                     NaN               NaN
# 2039024                      NaN                     NaN               NaN
# 489385                       NaN                     NaN               NaN
# 22313                        NaN                     NaN               NaN
#
#          sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 128651                NaN                 NaN                  NaN
# 258055                NaN                 NaN                  NaN
# 2039024               NaN                 NaN                  NaN
# 489385                NaN                 NaN                  NaN
# 22313                 NaN                 NaN                  NaN
#
#          sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 128651                     NaN                               NaN
# 258055                     NaN                               NaN
# 2039024                    NaN                               NaN
# 489385                     NaN                               NaN
# 22313                      NaN                               NaN
#
#          sec_app_collections_12_mths_ex_med  \
# 128651                                  NaN
# 258055                                  NaN
# 2039024                                 NaN
# 489385                                  NaN
# 22313                                   NaN
#
#          sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 128651                                   NaN             N           NaN
# 258055                                   NaN             N           NaN
# 2039024                                  NaN             N           NaN
# 489385                                   NaN             N           NaN
# 22313                                    NaN             N           NaN
#
#         hardship_reason hardship_status  deferral_term  hardship_amount  \
# 128651              NaN             NaN            NaN              NaN
# 258055              NaN             NaN            NaN              NaN
# 2039024             NaN             NaN            NaN              NaN
# 489385              NaN             NaN            NaN              NaN
# 22313               NaN             NaN            NaN              NaN
#
#         hardship_start_date hardship_end_date payment_plan_start_date  \
# 128651                  NaN               NaN                     NaN
# 258055                  NaN               NaN                     NaN
# 2039024                 NaN               NaN                     NaN
# 489385                  NaN               NaN                     NaN
# 22313                   NaN               NaN                     NaN
#
#          hardship_length  hardship_dpd hardship_loan_status  \
# 128651               NaN           NaN                  NaN
# 258055               NaN           NaN                  NaN
# 2039024              NaN           NaN                  NaN
# 489385               NaN           NaN                  NaN
# 22313                NaN           NaN                  NaN
#
#          orig_projected_additional_accrued_interest  \
# 128651                                          NaN
# 258055                                          NaN
# 2039024                                         NaN
# 489385                                          NaN
# 22313                                           NaN
#
#          hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 128651                              NaN                           NaN
# 258055                              NaN                           NaN
# 2039024                             NaN                           NaN
# 489385                              NaN                           NaN
# 22313                               NaN                           NaN
#
#         disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 128651                 Cash                    N                       NaN
# 258055                 Cash                    N                       NaN
# 2039024                Cash                    N                       NaN
# 489385                 Cash                    N                       NaN
# 22313                  Cash                    N                       NaN
#
#         settlement_status settlement_date  settlement_amount  \
# 128651                NaN             NaN                NaN
# 258055                NaN             NaN                NaN
# 2039024               NaN             NaN                NaN
# 489385                NaN             NaN                NaN
# 22313                 NaN             NaN                NaN
#
#          settlement_percentage  settlement_term
# 128651                     NaN              NaN
# 258055                     NaN              NaN
# 2039024                    NaN              NaN
# 489385                     NaN              NaN
# 22313                      NaN              NaN

# %%
df_accept.loan_status.unique()
# Out:
# array(['Charged Off', 'Fully Paid', 'Current', 'Late (31-120 days)',
#        'In Grace Period',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Charged Off', 'Default',
#        nan], dtype=object)

# %%
df_accept.loan_status.dropna(inplace=True)

# %%
df_accept.loan_status.unique()
# Out:
# array(['Charged Off', 'Fully Paid', 'Current', 'Late (31-120 days)',
#        'In Grace Period',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Charged Off', 'Default'],
#       dtype=object)

# %%
df_accept.loan_status.value_counts()
# Out:
# Fully Paid                                             323107
# Current                                                263689
# Charged Off                                             80382
# Late (31-120 days)                                       6371
# In Grace Period                                          2515
# Late (16-30 days)                                        1328
# Does not meet the credit policy. Status:Fully Paid        580
# Does not meet the credit policy. Status:Charged Off       222
# Default                                                     8
# Name: loan_status, dtype: int64

# %%
# now lets change the loan_status in two category only (0 = Default, 1 = None-Default)
default_column_names = ["Charged Off", "In Grace Period", "Does not meet the credit policy. Status:Charged Off", "Default" ]
def change_loan_status(status):
    if status in default_column_names:
        return 0
    else:
        return 1

# %%
df_accept.loan_status.unique()
# Out:
# array(['Charged Off', 'Fully Paid', 'Current', 'Late (31-120 days)',
#        'In Grace Period',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Charged Off', 'Default'],
#       dtype=object)

# %%
df_accept.head()
# Out:
#                 id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 128651    60983536        NaN    15000.0      15000.0          15000.0
# 258055    50486925        NaN    28000.0      28000.0          28000.0
# 2039024  125938434        NaN    15000.0      15000.0          15000.0
# 489385   127969743        NaN     5000.0       5000.0           5000.0
# 22313     66435932        NaN    21000.0      21000.0          21000.0
#
#                term  int_rate  installment grade sub_grade  \
# 128651    60 months      9.99       318.64     B        B3
# 258055    60 months     13.99       651.37     C        C4
# 2039024   36 months      6.72       461.24     A        A3
# 489385    36 months     10.91       163.49     B        B4
# 22313     60 months     12.59       473.42     C        C2
#
#                    emp_title emp_length home_ownership  annual_inc  \
# 128651         medical coder    5 years       MORTGAGE     65000.0
# 258055   Ingineering Manager  10+ years       MORTGAGE    148000.0
# 2039024    Operating Manager  10+ years       MORTGAGE    104000.0
# 489385                   NaN        NaN       MORTGAGE     32000.0
# 22313                  Owner    4 years           RENT    110000.0
#
#         verification_status   issue_d  loan_status pymnt_plan  \
# 128651         Not Verified  Oct-2015  Charged Off          n
# 258055             Verified  Jun-2015   Fully Paid          n
# 2039024            Verified  Dec-2017   Fully Paid          n
# 489385             Verified  Feb-2018      Current          n
# 22313       Source Verified  Dec-2015  Charged Off          n
#
#                                                        url desc  \
# 128651   https://lendingclub.com/browse/loanDetail.acti...  NaN
# 258055   https://lendingclub.com/browse/loanDetail.acti...  NaN
# 2039024  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 489385   https://lendingclub.com/browse/loanDetail.acti...  NaN
# 22313    https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                     purpose                    title zip_code addr_state  \
# 128651   debt_consolidation       Debt consolidation    707xx         LA
# 258055   debt_consolidation       Debt consolidation    750xx         TX
# 2039024         credit_card  Credit card refinancing    212xx         MD
# 489385   debt_consolidation       Debt consolidation    278xx         NC
# 22313    debt_consolidation       Debt consolidation    941xx         CA
#
#            dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 128651   21.27          1.0         Sep-2002           735.0            739.0
# 258055   14.77          0.0         Aug-2002           685.0            689.0
# 2039024  16.33          0.0         Jun-2001           720.0            724.0
# 489385   14.95          0.0         Mar-1983           675.0            679.0
# 22313    27.27          0.0         Dec-1999           700.0            704.0
#
#          inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 128651              0.0                     7.0                     NaN
# 258055              0.0                     NaN                     NaN
# 2039024             0.0                    31.0                     NaN
# 489385              0.0                     NaN                    46.0
# 22313               0.0                     NaN                     NaN
#
#          open_acc  pub_rec  revol_bal  revol_util  total_acc  \
# 128651       17.0      0.0     8766.0        25.9       40.0
# 258055       12.0      0.0    22748.0        92.5       30.0
# 2039024      13.0      0.0    19127.0        40.4       25.0
# 489385       19.0      1.0     8144.0        30.6       43.0
# 22313        11.0      0.0    74932.0        72.7       18.0
#
#         initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 128651                    w       0.00           0.00  11773.030000
# 258055                    w       0.00           0.00  36344.717659
# 2039024                   w       0.00           0.00  15922.762424
# 489385                    w    3379.03        3379.03   2122.340000
# 22313                     w       0.00           0.00   6814.040000
#
#          total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 128651          11773.03          8498.89        3274.14                 0.0
# 258055          36344.72         28000.00        8344.72                 0.0
# 2039024         15922.76         15000.00         922.76                 0.0
# 489385           2122.34          1620.97         501.37                 0.0
# 22313            6814.04          3218.67        2447.68                 0.0
#
#          recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 128651         0.00                   0.0000     Sep-2018           318.64
# 258055         0.00                   0.0000     Feb-2018         16195.77
# 2039024        0.00                   0.0000     Feb-2019         10401.88
# 489385         0.00                   0.0000     Mar-2019           163.49
# 22313       1147.69                 206.5842     Dec-2016           473.42
#
#         next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 128651           NaN           Mar-2019                 554.0
# 258055           NaN           Mar-2019                 689.0
# 2039024          NaN           Feb-2019                 764.0
# 489385      Apr-2019           Mar-2019                 689.0
# 22313            NaN           Oct-2018                 599.0
#
#          last_fico_range_low  collections_12_mths_ex_med  \
# 128651                 550.0                         0.0
# 258055                 685.0                         0.0
# 2039024                760.0                         0.0
# 489385                 685.0                         0.0
# 22313                  595.0                         0.0
#
#          mths_since_last_major_derog  policy_code application_type  \
# 128651                           NaN          1.0       Individual
# 258055                           NaN          1.0       Individual
# 2039024                          NaN          1.0       Individual
# 489385                           NaN          1.0       Individual
# 22313                            NaN          1.0       Individual
#
#          annual_inc_joint  dti_joint verification_status_joint  \
# 128651                NaN        NaN                       NaN
# 258055                NaN        NaN                       NaN
# 2039024               NaN        NaN                       NaN
# 489385                NaN        NaN                       NaN
# 22313                 NaN        NaN                       NaN
#
#          acc_now_delinq  tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  \
# 128651              0.0           0.0     251763.0          NaN          NaN
# 258055              0.0           0.0     219033.0          NaN          NaN
# 2039024             0.0           0.0     657988.0          0.0          2.0
# 489385              0.0           0.0      52250.0          1.0          0.0
# 22313               0.0           0.0      78967.0          NaN          NaN
#
#          open_il_12m  open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  \
# 128651           NaN          NaN                 NaN           NaN      NaN
# 258055           NaN          NaN                 NaN           NaN      NaN
# 2039024          0.0          1.0                21.0       17750.0     46.0
# 489385           0.0          0.0                71.0           0.0      NaN
# 22313            NaN          NaN                 NaN           NaN      NaN
#
#          open_rv_12m  open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  \
# 128651           NaN          NaN         NaN       NaN           33800.0
# 258055           NaN          NaN         NaN       NaN           24600.0
# 2039024          0.0          1.0      6318.0      43.0           47400.0
# 489385           1.0          8.0      2846.0      33.0           26600.0
# 22313            NaN          NaN         NaN       NaN          103000.0
#
#          inq_fi  total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 128651      NaN          NaN           NaN                   6.0      14810.0
# 258055      NaN          NaN           NaN                   3.0      19912.0
# 2039024     0.0          0.0           1.0                   3.0      50614.0
# 489385      3.0          0.0           0.0                   8.0       3074.0
# 22313       NaN          NaN           NaN                   1.0       7179.0
#
#          bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 128651          17098.0     18.6                       0.0          0.0
# 258055           1488.0     92.0                       0.0          0.0
# 2039024         24273.0     44.1                       0.0          0.0
# 489385           2319.0     67.3                       0.0          0.0
# 22313           22194.0     75.9                       0.0          0.0
#
#          mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 128651                156.0                 133.0                    5.0
# 258055                151.0                 153.0                   25.0
# 2039024                36.0                 198.0                   24.0
# 489385                175.0                 181.0                    6.0
# 22313                 119.0                 192.0                   12.0
#
#          mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 128651              5.0       1.0                  14.0
# 258055             13.0       3.0                  43.0
# 2039024            19.0       5.0                  50.0
# 489385              6.0       1.0                  13.0
# 22313              12.0       0.0                  40.0
#
#          mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 128651                        NaN                    3.0
# 258055                        NaN                   13.0
# 2039024                      31.0                   11.0
# 489385                        NaN                   15.0
# 22313                         NaN                   17.0
#
#          mths_since_recent_revol_delinq  num_accts_ever_120_pd  \
# 128651                              NaN                    0.0
# 258055                              NaN                    0.0
# 2039024                            31.0                    0.0
# 489385                              NaN                    0.0
# 22313                               NaN                    0.0
#
#          num_actv_bc_tl  num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  \
# 128651              3.0              5.0          5.0        7.0       23.0
# 258055              5.0              7.0          6.0       10.0       15.0
# 2039024             5.0              5.0          7.0       14.0        3.0
# 489385              4.0              9.0          5.0       12.0        3.0
# 22313               8.0             10.0          8.0        8.0        5.0
#
#          num_op_rev_tl  num_rev_accts  num_rev_tl_bal_gt_0  num_sats  \
# 128651             8.0           16.0                  5.0      17.0
# 258055             8.0           12.0                  7.0      12.0
# 2039024            8.0           17.0                  5.0      13.0
# 489385            17.0           37.0                  9.0      18.0
# 22313             10.0           13.0                 10.0      11.0
#
#          num_tl_120dpd_2m  num_tl_30dpd  num_tl_90g_dpd_24m  \
# 128651                0.0           0.0                 0.0
# 258055                0.0           0.0                 0.0
# 2039024               0.0           0.0                 0.0
# 489385                0.0           0.0                 0.0
# 22313                 0.0           0.0                 0.0
#
#          num_tl_op_past_12m  pct_tl_nvr_dlq  percent_bc_gt_75  \
# 128651                  2.0            97.5               0.0
# 258055                  0.0           100.0              80.0
# 2039024                 0.0            96.0              28.6
# 489385                  1.0           100.0              60.0
# 22313                   1.0           100.0              62.5
#
#          pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  total_bal_ex_mort  \
# 128651                    0.0        0.0         307402.0            46097.0
# 258055                    0.0        0.0         260249.0            52111.0
# 2039024                   0.0        0.0         745762.0            36877.0
# 489385                    1.0        0.0          99015.0             9200.0
# 22313                     0.0        0.0         123755.0            78967.0
#
#          total_bc_limit  total_il_high_credit_limit  revol_bal_joint  \
# 128651          21000.0                     46652.0              NaN
# 258055          18700.0                     41749.0              NaN
# 2039024         43400.0                     38962.0              NaN
# 489385           7100.0                         0.0              NaN
# 22313           92000.0                     20755.0              NaN
#
#          sec_app_fico_range_low  sec_app_fico_range_high  \
# 128651                      NaN                      NaN
# 258055                      NaN                      NaN
# 2039024                     NaN                      NaN
# 489385                      NaN                      NaN
# 22313                       NaN                      NaN
#
#         sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 128651                       NaN                     NaN               NaN
# 258055                       NaN                     NaN               NaN
# 2039024                      NaN                     NaN               NaN
# 489385                       NaN                     NaN               NaN
# 22313                        NaN                     NaN               NaN
#
#          sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 128651                NaN                 NaN                  NaN
# 258055                NaN                 NaN                  NaN
# 2039024               NaN                 NaN                  NaN
# 489385                NaN                 NaN                  NaN
# 22313                 NaN                 NaN                  NaN
#
#          sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 128651                     NaN                               NaN
# 258055                     NaN                               NaN
# 2039024                    NaN                               NaN
# 489385                     NaN                               NaN
# 22313                      NaN                               NaN
#
#          sec_app_collections_12_mths_ex_med  \
# 128651                                  NaN
# 258055                                  NaN
# 2039024                                 NaN
# 489385                                  NaN
# 22313                                   NaN
#
#          sec_app_mths_since_last_major_derog hardship_flag hardship_type  \
# 128651                                   NaN             N           NaN
# 258055                                   NaN             N           NaN
# 2039024                                  NaN             N           NaN
# 489385                                   NaN             N           NaN
# 22313                                    NaN             N           NaN
#
#         hardship_reason hardship_status  deferral_term  hardship_amount  \
# 128651              NaN             NaN            NaN              NaN
# 258055              NaN             NaN            NaN              NaN
# 2039024             NaN             NaN            NaN              NaN
# 489385              NaN             NaN            NaN              NaN
# 22313               NaN             NaN            NaN              NaN
#
#         hardship_start_date hardship_end_date payment_plan_start_date  \
# 128651                  NaN               NaN                     NaN
# 258055                  NaN               NaN                     NaN
# 2039024                 NaN               NaN                     NaN
# 489385                  NaN               NaN                     NaN
# 22313                   NaN               NaN                     NaN
#
#          hardship_length  hardship_dpd hardship_loan_status  \
# 128651               NaN           NaN                  NaN
# 258055               NaN           NaN                  NaN
# 2039024              NaN           NaN                  NaN
# 489385               NaN           NaN                  NaN
# 22313                NaN           NaN                  NaN
#
#          orig_projected_additional_accrued_interest  \
# 128651                                          NaN
# 258055                                          NaN
# 2039024                                         NaN
# 489385                                          NaN
# 22313                                           NaN
#
#          hardship_payoff_balance_amount  hardship_last_payment_amount  \
# 128651                              NaN                           NaN
# 258055                              NaN                           NaN
# 2039024                             NaN                           NaN
# 489385                              NaN                           NaN
# 22313                               NaN                           NaN
#
#         disbursement_method debt_settlement_flag debt_settlement_flag_date  \
# 128651                 Cash                    N                       NaN
# 258055                 Cash                    N                       NaN
# 2039024                Cash                    N                       NaN
# 489385                 Cash                    N                       NaN
# 22313                  Cash                    N                       NaN
#
#         settlement_status settlement_date  settlement_amount  \
# 128651                NaN             NaN                NaN
# 258055                NaN             NaN                NaN
# 2039024               NaN             NaN                NaN
# 489385                NaN             NaN                NaN
# 22313                 NaN             NaN                NaN
#
#          settlement_percentage  settlement_term
# 128651                     NaN              NaN
# 258055                     NaN              NaN
# 2039024                    NaN              NaN
# 489385                     NaN              NaN
# 22313                      NaN              NaN

# %%
type(df_accept.index)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
temp = df_accept.loan_status == 'Current'
type(temp.index)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
# lets remove the loan which are current
df_accept[temp]
# Out:
# /mnt/BA504CE3504CA7C9/Work/Python/Pract/ML/env/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-55-d2f2a03d208f> in <module>
#       1 # lets remove the loan which are current
# ----> 2 df_accept[temp]
#
# /mnt/BA504CE3504CA7C9/Work/Python/Pract/ML/env/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2789         # Do we have a (boolean) 1d indexer?
#    2790         if com.is_bool_indexer(key):
# -> 2791             return self._getitem_bool_array(key)
#    2792
#    2793         # We are left with two options: a single key, and a collection of keys,
#
# /mnt/BA504CE3504CA7C9/Work/Python/Pract/ML/env/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    2841         # check_bool_indexer will throw exception if Series key cannot
#    2842         # be reindexed to match DataFrame rows
# -> 2843         key = check_bool_indexer(self.index, key)
#    2844         indexer = key.nonzero()[0]
#    2845         return self._take_with_is_copy(indexer, axis=0)
#
# /mnt/BA504CE3504CA7C9/Work/Python/Pract/ML/env/lib/python3.7/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2316         if mask.any():
#    2317             raise IndexingError(
# -> 2318                 "Unalignable boolean Series provided as "
#    2319                 "indexer (index of the boolean Series and of "
#    2320                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
df_accept.drop(current_loan.index, inplace=True)
df_accept.loan_status.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-efe3bb6f262a> in <module>
# ----> 1 df_accept.drop(current_loan.index, inplace=True)
#       2 df_accept.loan_status.value_counts()
#
# NameError: name 'current_loan' is not defined

# %%
df_accept.loan_status = df_accept.loan_status.apply(change_loan_status)

# %%
# calculating for missing data percentage
missing_value_count = df_accept.isnull().sum()
missing_per = missing_value_count / len(df_accept) * 100
missing_per

# %%
# missing data more then 50%
missing_data_columns = missing_per[missing_per >= 40].index.values

# %%
missing_data_columns

# %%
df_accept.drop(columns=missing_data_columns, inplace=True)

# %%
len(df_accept.columns)

# %%
df_accept.loan_status.value_counts()

# %%
# now lets work on NA values
null_count = df_accept.isnull().sum()
total_count = len(df_accept)
per = null_count / total_count * 100
missing_df = pd.concat([null_count, per], axis=1)
missing_df.columns = ["Null Counts", "Percentage"]
missing_df.sort_values(by="Percentage", ascending=False).T
